# %% [markdown]
# # Electron Trajecotory With Initial Conditions
# Place a set of intial conditions into the code directly below. These intial conditions will then be run through the multiple differen python simulations as shown below each with the intial conditions listed. To run a specfic code, navigate to the listed section. All code will be discribed in a header above the code section. After you change the input file restart the Kernal to put in a new set of parameters

# %%
# %%writefile input/ElectronTrajectory_input.py
#This line will create ElectronTrajectory_input.py input file in the subfolder 'input'.

#Intial Electron Paramters 
y0_rb = 0.4 #initial transverse position in y0/rb
dy_rb = 0.05 #initial beam width in dy/rb

#Wakefield Parameters used in the diffraction pattern code
#Electrons begin being fired from y0top to y0bot
y0top = 1        
y0bot = -1 

#Screen Distance
distance = 0.065 #Meters

#Number of Electrons Fired (Animation)
N = 1000 #number of electrons

# %% [markdown]
# # 2D Electron Trajecotry through a Cylinder and the difference between F-tilda points
#
# There are two approximations that are examined when we analyze the distacne a beam is from the wakefield when the beam is at minimum width. The first approximation assumes dy is small. The second approximation assumes y0 is small. Both are effective in spefcific ranges. This distance is called F-tilda. The code below plots the intersection of an electron at the top of the beam, and an electron at the bottom of a beam and then determines the distance of both approximations from the true x-minimum value.

# %%
# %run 2D-Cylinder/electron_main.py input.ElectronTrajectory_input

# %% [markdown]
# # Difraction Pattern of Multiple Electron Beams
#
# In this section we will fire many beams across the entirety of a wakefield. The resulting image will display how they intersect across x, and how many intersect specfic locations.

# %%
# %run 2D-Cylinder/diffraction_main.py input.ElectronTrajectory_input

# %% [markdown]
# # Diffraction pattern Animation
#
# When you imput an N number of electrons into the input file, the python code will shoot that many electrons in a line into the wakefield. It will then trace their ballistic trajectory. At an input "distance" away, the code will save where the trajectory of an electron crosses this distance or "screen." The result is an animation. The animation dynamically examines where an "N" number of electrons land as a mask is pulled down. This will show where the focal points of electrons congragate at a specfic distance.
#
# ***Note the Animation will save as an html file to the main folder

# %%
# %run 2D-Cylinder/diffraction_anim_main.py input.ElectronTrajectory_input
